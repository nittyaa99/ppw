# %% [markdown]
# # **Tugas 7 - Keyword Extraction Menggunakan Centrality**

# %% [markdown]
# Nama : Isnita Widyur Rahmah
# NIM : 220411100048
# Kelas : IF 7A

# %% [markdown]
# Link Project : https://github.com/nittyaa99/ppw

# %% [markdown]
# ## Install Pustaka Python

# %%
# !pip install nltk pandas requests beautifulsoup4
# Out:
# Requirement already satisfied: nltk in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (3.8.1)
# Requirement already satisfied: pandas in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (2.0.3)
# Requirement already satisfied: requests in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (4.12.3)
# Requirement already satisfied: click in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (from nltk) (2024.4.16)
# Requirement already satisfied: tqdm in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (from nltk) (4.66.2)
# Requirement already satisfied: joblib in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (from nltk) (1.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.25.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\isnita\appdata\roaming\python\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (from requests) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: six>=1.5 in c:\users\isnita\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: colorama in c:\users\isnita\appdata\local\programs\python\python310\lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip available: 22.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Impor Pustaka

# %%
import numpy as np
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup

import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
from nltk.tokenize import sent_tokenize , word_tokenize
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ISNITA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ISNITA\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ISNITA\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Crawling Data Artikel Berita Menggunakan Python
# melakukan crawling untuk mengambil judul, isi, tanggal, dan kategori artikel dari URL yang diberikan, dan menyajikan data tersebut dalam bentuk DataFrame untuk kemudahan analisis lebih lanjut.

# %%
def crawl_article(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Memastikan permintaan berhasil
        soup = BeautifulSoup(response.content, 'html.parser')

        # Mengambil judul
        title_element = soup.find('h1', class_='text-cnn_black')
        title = title_element.get_text().strip() if title_element else 'Judul tidak ditemukan'

        # Mengambil Isi
        content_div = soup.find('div', class_='detail-text')
        content = "\n".join([p.get_text().strip() for p in content_div.find_all('p')]) if content_div else 'Isi artikel tidak ditemukan'

        # Mengambil tanggal
        date_div = soup.find('div', class_='text-cnn_grey text-sm mb-4')
        date_text = date_div.text.strip() if date_div else 'Tanggal tidak ditemukan'

        # Mengambil kategori
        category_meta = soup.find("meta", attrs={'name': 'dtk:namakanal'})
        category = category_meta['content'].strip() if category_meta and 'content' in category_meta.attrs else 'Kategori tidak ditemukan'

        return {'Judul': title, 'Isi': content, 'Tanggal': date_text, 'Kategori': category}
    except requests.RequestException as e:
        print(f"Error fetching article: {e}")
        return None

article_url = input("Masukkan URL artikel: ")

# Melakukan crawl pada satu artikel
article = crawl_article(article_url)

df = pd.DataFrame([article])  # Membuat DataFrame dari dictionary
df
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# Cell In[3], line 28
#      25         print(f"Error fetching article: {e}")
#      26         return None
# ---> 28 article_url = input("Masukkan URL artikel: ")
#      30 # Melakukan crawl pada satu artikel
#      31 article = crawl_article(article_url)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py:1201, in Kernel.raw_input(self, prompt)
#    1199 if not self._allow_stdin:
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
# -> 1201     raise StdinNotImplementedError(msg)
#    1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %% [markdown]
# ## Transformasi Teks Menjadi Huruf Kecil
# mengubah semua teks dalam kolom Isi menjadi huruf kecil dan menyimpannya dalam kolom baru.

# %%
# Fungsi untuk mengubah teks menjadi huruf kecil
def clean_lower(text):
    if isinstance(text, str):
        return text.lower()
    return text

df['lower case'] = df['Isi'].apply(clean_lower)
df['lower case']
# Out:
# 0    timnas indonesia akan menghadapi bahrain dalam...
# Name: lower case, dtype: object

# %% [markdown]
# ## Pembersihan Teks dari Tanda Baca dan Angka
# membersihkan teks dari tanda baca dan angka, serta menghapus karakter yang tidak diinginkan, dan menyimpannya dalam kolom baru.

# %%
# Fungsi untuk membersihkan tanda baca dan angka (menghapus koma)
def clean_punct(text):
    if isinstance(text, str):
        clean_patterns = re.compile(r'[0-9]|[/(){}\[\]\|@,;_]|[^a-z .]+')  # Koma dihilangkan dari pengecualian
        text = clean_patterns.sub(' ', text)
        text = re.sub(r'\s+', ' ', text).strip()
        return text
    return text

df['tanda baca'] = df['lower case'].apply(clean_punct)
df['tanda baca']
# Out:
# 0    timnas indonesia akan menghadapi bahrain dalam...
# Name: tanda baca, dtype: object

# %% [markdown]
# ## Normalisasi Spasi dalam Teks
# melakukan normalisasi spasi dalam teks dengan mengganti beberapa spasi berturut-turut menjadi satu spasi dan menghapus spasi di awal dan akhir.

# %%
# Fungsi untuk normalisasi spasi
def _normalize_whitespace(text):
    if isinstance(text, str):
        corrected = re.sub(r'\s+', ' ', text)
        return corrected.strip()
    return text

df['spasi'] = df['tanda baca'].apply(_normalize_whitespace)
df['spasi']
# Out:
# 0    timnas indonesia akan menghadapi bahrain dalam...
# Name: spasi, dtype: object

# %% [markdown]
# ## Tokenisasi Teks Menjadi Kata
# melakukan tokenisasi pada teks yang telah dinormalisasi, memecahnya menjadi daftar kata atau token, dan menyimpannya dalam kolom baru.

# %%
# Tokenisasi
def tokenize_text(text):
    if isinstance(text, str):
        return word_tokenize(text)
    return text

df['token'] = df['spasi'].apply(tokenize_text)
df['token']
# Out:
# 0    [timnas, indonesia, akan, menghadapi, bahrain,...
# Name: token, dtype: object

# %% [markdown]
# ## Pembersihan Stopwords dari Token
# membersihkan daftar token dari kata-kata umum yang tidak memberikan makna penting (stopwords), sehingga hanya kata-kata yang relevan yang tersisa untuk analisis lebih lanjut.

# %%
# Pembersihan stopwords setelah tokenisasi
def clean_stopwords(tokens):
    if isinstance(tokens, list):
        stopword = set(stopwords.words('indonesian'))
        filtered_tokens = [word for word in tokens if word not in stopword]
        return filtered_tokens
    return tokens

df['stopwords'] = df['token'].apply(clean_stopwords)
df['stopwords']
# Out:
# 0    [timnas, indonesia, menghadapi, bahrain, laga,...
# Name: stopwords, dtype: object

# %% [markdown]
# ## Penggabungan Token Menjadi Teks yang Diproses
# menggabungkan kembali daftar token yang telah dibersihkan menjadi string utuh, yang kemudian dapat digunakan untuk analisis lebih lanjut.

# %%
# Gabungkan kembali token menjadi string
df['processed_text'] = df['stopwords'].apply(lambda tokens: ' '.join(tokens) if isinstance(tokens, list) else '')

prep_result = df['processed_text'].to_dict()
print(prep_result)
# Out:
# {0: 'timnas indonesia menghadapi bahrain laga kualifikasi piala dunia maret . laga momen krusial perebutan tiket piala dunia . duel timnas indonesia vs bahrain dijadwalkan maret . duel matchday ketujuh alias masuk matchday babak ketiga kualifikasi piala dunia . kondisi indonesia vs bahrain momen krusial tim . tim menjaga peluang lolos piala dunia perebutan terjaga . advertisement scroll to continue with content berkaca kondisi klasemen grup c kualifikasi piala dunia zona asia pertarungan perebutan posisi klasemen ketat . tim tertinggal perebutan posisi peluang finis posisi diyakini terbuka lebar . bahrain perubahan lokasi venue laga timnas indonesia vs bahrain indonesia kerugian skuad garuda . bahrain perubahan lokasi pertandingan alasan keselamatan pemain . mengecam serangan serangan media sosial dilancarkan penggemar timnas indonesia . kekecewaan penggemar timnas indonesia tumpah lantaran insiden kontroversial bahrain vs indonesia . bahrain mencetak gol menit kesembilan injury time injury time ditetapkan enam menit . sejalan asosiasi sepak bola bahrain keselamatan anggotanya anggota tim nasional asosiasi proses menghubungi fifa afc perilaku diterima asosiasi sepak bola bahrain ancaman hinaan pencemaran nama mempengaruhi keselamatan anggota tim nasional bertanding kota jakarta . asosiasi mengajukan permintaan pemindahan pertandingan indonesia menjaga keselamatan pemain tim nasional tulis asosiasi sepak bola bahrain bfa pernyataannya . gambas video cnn'}

# %% [markdown]
# ## Kumpulan Kalimat dan Kata Unik dari Teks Terproses
# menyiapkan data untuk analisis lebih lanjut dengan membuat kumpulan kalimat dari teks yang telah diproses dan mengumpulkan kata-kata unik

# %%
# Membuat kumpulan kalimat
sentences = []
for p in df['processed_text']:
  sentences.extend(sent_tokenize(p))

# Membuat kumpulan kata unik
vocabulary = set()
for sentence in sentences:
  for word in sentence.split():
    vocabulary.add(word)

print(sentences)
print(vocabulary)
# Out:
# ['timnas indonesia menghadapi bahrain laga kualifikasi piala dunia maret .', 'laga momen krusial perebutan tiket piala dunia .', 'duel timnas indonesia vs bahrain dijadwalkan maret .', 'duel matchday ketujuh alias masuk matchday babak ketiga kualifikasi piala dunia .', 'kondisi indonesia vs bahrain momen krusial tim .', 'tim menjaga peluang lolos piala dunia perebutan terjaga .', 'advertisement scroll to continue with content berkaca kondisi klasemen grup c kualifikasi piala dunia zona asia pertarungan perebutan posisi klasemen ketat .', 'tim tertinggal perebutan posisi peluang finis posisi diyakini terbuka lebar .', 'bahrain perubahan lokasi venue laga timnas indonesia vs bahrain indonesia kerugian skuad garuda .', 'bahrain perubahan lokasi pertandingan alasan keselamatan pemain .', 'mengecam serangan serangan media sosial dilancarkan penggemar timnas indonesia .', 'kekecewaan penggemar timnas indonesia tumpah lantaran insiden kontroversial bahrain vs indonesia .', 'bahrain mencetak gol menit kesembilan injury time injury time ditetapkan enam menit .', 'sejalan asosiasi sepak bola bahrain keselamatan anggotanya anggota tim nasional asosiasi proses menghubungi fifa afc perilaku diterima asosiasi sepak bola bahrain ancaman hinaan pencemaran nama mempengaruhi keselamatan anggota tim nasional bertanding kota jakarta .', 'asosiasi mengajukan permintaan pemindahan pertandingan indonesia menjaga keselamatan pemain tim nasional tulis asosiasi sepak bola bahrain bfa pernyataannya .', 'gambas video cnn']
# {'ketat', 'kualifikasi', 'pertarungan', 'kerugian', 'ketujuh', 'keselamatan', 'sepak', 'pemain', 'c', 'gambas', 'garuda', 'timnas', 'peluang', 'time', 'insiden', 'asia', 'tumpah', 'video', 'finis', 'perubahan', 'grup', 'dijadwalkan', 'kota', 'diyakini', 'pencemaran', 'advertisement', 'serangan', '.', 'kesembilan', 'anggota', 'ditetapkan', 'with', 'venue', 'bertanding', 'menghadapi', 'pernyataannya', 'perilaku', 'terbuka', 'injury', 'mengajukan', 'content', 'alasan', 'posisi', 'lokasi', 'scroll', 'bola', 'menit', 'tim', 'media', 'cnn', 'anggotanya', 'hinaan', 'bfa', 'tiket', 'proses', 'berkaca', 'permintaan', 'indonesia', 'tertinggal', 'dunia', 'fifa', 'perebutan', 'kondisi', 'gol', 'lantaran', 'piala', 'mempengaruhi', 'ancaman', 'momen', 'jakarta', 'vs', 'menghubungi', 'klasemen', 'kontroversial', 'zona', 'menjaga', 'terjaga', 'pemindahan', 'ketiga', 'sejalan', 'tulis', 'penggemar', 'bahrain', 'sosial', 'babak', 'duel', 'lolos', 'skuad', 'continue', 'enam', 'alias', 'mengecam', 'masuk', 'pertandingan', 'afc', 'krusial', 'dilancarkan', 'nama', 'to', 'diterima', 'matchday', 'laga', 'asosiasi', 'kekecewaan', 'nasional', 'maret', 'mencetak', 'lebar'}

# %% [markdown]
# ## Membuat DataFrame untuk Frekuensi Kata dalam Kalimat
# mengonversi kumpulan kalimat menjadi representasi vektor frekuensi kata dalam bentuk DataFrame.

# %%
pd.set_option('future.no_silent_downcasting', True)
df = pd.DataFrame(columns=list(vocabulary), index=sentences)

# Mengisi nilai kosong dengan 0
df = df.fillna(0)  # Fill with 0s

# Menghitung nilai setiap kata pada kalimat
for i, sentence in enumerate(sentences):
  for word in sentence.split():
    df.loc[sentence, word] += 1

# Melihat isi Dataframe
df
# Out:
#                                                    ketat kualifikasi  \
# timnas indonesia menghadapi bahrain laga kualif...     0           1
# laga momen krusial perebutan tiket piala dunia .       0           0
# duel timnas indonesia vs bahrain dijadwalkan ma...     0           0
# duel matchday ketujuh alias masuk matchday baba...     0           1
# kondisi indonesia vs bahrain momen krusial tim .       0           0
# tim menjaga peluang lolos piala dunia perebutan...     0           0
# advertisement scroll to continue with content b...     1           1
# tim tertinggal perebutan posisi peluang finis p...     0           0
# bahrain perubahan lokasi venue laga timnas indo...     0           0
# bahrain perubahan lokasi pertandingan alasan ke...     0           0
# mengecam serangan serangan media sosial dilanca...     0           0
# kekecewaan penggemar timnas indonesia tumpah la...     0           0
# bahrain mencetak gol menit kesembilan injury ti...     0           0
# sejalan asosiasi sepak bola bahrain keselamatan...     0           0
# asosiasi mengajukan permintaan pemindahan perta...     0           0
# gambas video cnn                                       0           0
#
#                                                    pertarungan kerugian  \
# timnas indonesia menghadapi bahrain laga kualif...           0        0
# laga momen krusial perebutan tiket piala dunia .             0        0
# duel timnas indonesia vs bahrain dijadwalkan ma...           0        0
# duel matchday ketujuh alias masuk matchday baba...           0        0
# kondisi indonesia vs bahrain momen krusial tim .             0        0
# tim menjaga peluang lolos piala dunia perebutan...           0        0
# advertisement scroll to continue with content b...           1        0
# tim tertinggal perebutan posisi peluang finis p...           0        0
# bahrain perubahan lokasi venue laga timnas indo...           0        1
# bahrain perubahan lokasi pertandingan alasan ke...           0        0
# mengecam serangan serangan media sosial dilanca...           0        0
# kekecewaan penggemar timnas indonesia tumpah la...           0        0
# bahrain mencetak gol menit kesembilan injury ti...           0        0
# sejalan asosiasi sepak bola bahrain keselamatan...           0        0
# asosiasi mengajukan permintaan pemindahan perta...           0        0
# gambas video cnn                                             0        0
#
#                                                    ketujuh keselamatan sepak  \
# timnas indonesia menghadapi bahrain laga kualif...       0           0     0
# laga momen krusial perebutan tiket piala dunia .         0           0     0
# duel timnas indonesia vs bahrain dijadwalkan ma...       0           0     0
# duel matchday ketujuh alias masuk matchday baba...       1           0     0
# kondisi indonesia vs bahrain momen krusial tim .         0           0     0
# tim menjaga peluang lolos piala dunia perebutan...       0           0     0
# advertisement scroll to continue with content b...       0           0     0
# tim tertinggal perebutan posisi peluang finis p...       0           0     0
# bahrain perubahan lokasi venue laga timnas indo...       0           0     0
# bahrain perubahan lokasi pertandingan alasan ke...       0           1     0
# mengecam serangan serangan media sosial dilanca...       0           0     0
# kekecewaan penggemar timnas indonesia tumpah la...       0           0     0
# bahrain mencetak gol menit kesembilan injury ti...       0           0     0
# sejalan asosiasi sepak bola bahrain keselamatan...       0           2     2
# asosiasi mengajukan permintaan pemindahan perta...       0           1     1
# gambas video cnn                                         0           0     0
#
#                                                    pemain  c gambas  ... to  \
# timnas indonesia menghadapi bahrain laga kualif...      0  0      0  ...  0
# laga momen krusial perebutan tiket piala dunia .        0  0      0  ...  0
# duel timnas indonesia vs bahrain dijadwalkan ma...      0  0      0  ...  0
# duel matchday ketujuh alias masuk matchday baba...      0  0      0  ...  0
# kondisi indonesia vs bahrain momen krusial tim .        0  0      0  ...  0
# tim menjaga peluang lolos piala dunia perebutan...      0  0      0  ...  0
# advertisement scroll to continue with content b...      0  1      0  ...  1
# tim tertinggal perebutan posisi peluang finis p...      0  0      0  ...  0
# bahrain perubahan lokasi venue laga timnas indo...      0  0      0  ...  0
# bahrain perubahan lokasi pertandingan alasan ke...      1  0      0  ...  0
# mengecam serangan serangan media sosial dilanca...      0  0      0  ...  0
# kekecewaan penggemar timnas indonesia tumpah la...      0  0      0  ...  0
# bahrain mencetak gol menit kesembilan injury ti...      0  0      0  ...  0
# sejalan asosiasi sepak bola bahrain keselamatan...      0  0      0  ...  0
# asosiasi mengajukan permintaan pemindahan perta...      1  0      0  ...  0
# gambas video cnn                                        0  0      1  ...  0
#
#                                                    diterima matchday laga  \
# timnas indonesia menghadapi bahrain laga kualif...        0        0    1
# laga momen krusial perebutan tiket piala dunia .          0        0    1
# duel timnas indonesia vs bahrain dijadwalkan ma...        0        0    0
# duel matchday ketujuh alias masuk matchday baba...        0        2    0
# kondisi indonesia vs bahrain momen krusial tim .          0        0    0
# tim menjaga peluang lolos piala dunia perebutan...        0        0    0
# advertisement scroll to continue with content b...        0        0    0
# tim tertinggal perebutan posisi peluang finis p...        0        0    0
# bahrain perubahan lokasi venue laga timnas indo...        0        0    1
# bahrain perubahan lokasi pertandingan alasan ke...        0        0    0
# mengecam serangan serangan media sosial dilanca...        0        0    0
# kekecewaan penggemar timnas indonesia tumpah la...        0        0    0
# bahrain mencetak gol menit kesembilan injury ti...        0        0    0
# sejalan asosiasi sepak bola bahrain keselamatan...        1        0    0
# asosiasi mengajukan permintaan pemindahan perta...        0        0    0
# gambas video cnn                                          0        0    0
#
#                                                    asosiasi kekecewaan  \
# timnas indonesia menghadapi bahrain laga kualif...        0          0
# laga momen krusial perebutan tiket piala dunia .          0          0
# duel timnas indonesia vs bahrain dijadwalkan ma...        0          0
# duel matchday ketujuh alias masuk matchday baba...        0          0
# kondisi indonesia vs bahrain momen krusial tim .          0          0
# tim menjaga peluang lolos piala dunia perebutan...        0          0
# advertisement scroll to continue with content b...        0          0
# tim tertinggal perebutan posisi peluang finis p...        0          0
# bahrain perubahan lokasi venue laga timnas indo...        0          0
# bahrain perubahan lokasi pertandingan alasan ke...        0          0
# mengecam serangan serangan media sosial dilanca...        0          0
# kekecewaan penggemar timnas indonesia tumpah la...        0          1
# bahrain mencetak gol menit kesembilan injury ti...        0          0
# sejalan asosiasi sepak bola bahrain keselamatan...        3          0
# asosiasi mengajukan permintaan pemindahan perta...        2          0
# gambas video cnn                                          0          0
#
#                                                    nasional maret mencetak  \
# timnas indonesia menghadapi bahrain laga kualif...        0     1        0
# laga momen krusial perebutan tiket piala dunia .          0     0        0
# duel timnas indonesia vs bahrain dijadwalkan ma...        0     1        0
# duel matchday ketujuh alias masuk matchday baba...        0     0        0
# kondisi indonesia vs bahrain momen krusial tim .          0     0        0
# tim menjaga peluang lolos piala dunia perebutan...        0     0        0
# advertisement scroll to continue with content b...        0     0        0
# tim tertinggal perebutan posisi peluang finis p...        0     0        0
# bahrain perubahan lokasi venue laga timnas indo...        0     0        0
# bahrain perubahan lokasi pertandingan alasan ke...        0     0        0
# mengecam serangan serangan media sosial dilanca...        0     0        0
# kekecewaan penggemar timnas indonesia tumpah la...        0     0        0
# bahrain mencetak gol menit kesembilan injury ti...        0     0        1
# sejalan asosiasi sepak bola bahrain keselamatan...        2     0        0
# asosiasi mengajukan permintaan pemindahan perta...        1     0        0
# gambas video cnn                                          0     0        0
#
#                                                    lebar
# timnas indonesia menghadapi bahrain laga kualif...     0
# laga momen krusial perebutan tiket piala dunia .       0
# duel timnas indonesia vs bahrain dijadwalkan ma...     0
# duel matchday ketujuh alias masuk matchday baba...     0
# kondisi indonesia vs bahrain momen krusial tim .       0
# tim menjaga peluang lolos piala dunia perebutan...     0
# advertisement scroll to continue with content b...     0
# tim tertinggal perebutan posisi peluang finis p...     1
# bahrain perubahan lokasi venue laga timnas indo...     0
# bahrain perubahan lokasi pertandingan alasan ke...     0
# mengecam serangan serangan media sosial dilanca...     0
# kekecewaan penggemar timnas indonesia tumpah la...     0
# bahrain mencetak gol menit kesembilan injury ti...     0
# sejalan asosiasi sepak bola bahrain keselamatan...     0
# asosiasi mengajukan permintaan pemindahan perta...     0
# gambas video cnn                                       0
#
# [16 rows x 108 columns]

# %% [markdown]
# ## Menghitung dan Menampilkan Frekuensi Kata Teratas
# menghitung dan menampilkan kata-kata dengan frekuensi tertinggi dari DataFrame, memberikan wawasan tentang kata-kata yang paling umum muncul dalam kumpulan kalimat.

# %%
# Menghitung jumlah kemunculan pada tiap kata
word_frequencies = df.sum(axis=0)

# Mengurutkan berdasarkan jumlah kemunculan kata
sorted_word_frequencies = word_frequencies.sort_values(ascending=False)

# Menampilkan kata teratas
keyword = 3

for i, (word, freq) in enumerate(sorted_word_frequencies.items()):
    if i < keyword:
        print(f"Rank {i+1}: {word} (Frequency: {freq})")
# Out:
# Rank 1: . (Frequency: 15)
# Rank 2: bahrain (Frequency: 11)
# Rank 3: indonesia (Frequency: 9)
